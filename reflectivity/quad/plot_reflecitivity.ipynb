# %%
import numpy as np
import matplotlib.pyplot as plt
import glob

# %matplotlib nbagg

# %%
def cos(theta):
    return np.cos(theta*np.pi/180)

# %%
files = glob.glob('*.txt')

fig, ax = plt.subplots()
for file in files:
    M = np.loadtxt(file)
    ax.semilogy(M[:,0]-90, M[:,1], label=file[:-4])

ax.set_xlabel(r'$\theta$ ($^\circ$)')
ax.set_ylabel('I')
ax.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
def get_peak(file):
    M = np.loadtxt(file)
    peakregioninds = np.logical_and(M[:,0]>(90+19), M[:,0]<(90+21))
    M_region = M[peakregioninds,:]
    peak_ind = np.argmax(M_region[:,1])
    return M_region[peak_ind]

# %%
info = [[file[:-4], get_peak(file)] for file in files]
info
# Out:
# [['dynamic_pi', array([  1.10060000e+02,   5.74757600e-02])],
#  ['dynamic_sigma', array([  1.10060000e+02,   9.50217700e-02])]]

# %%
ratio = info[0][1][1]/info[1][1][1]
print(r"Dynamical diffraction pi/sigma {:.3} \nCompared to {:.3f} using the $\cos(2\theta)^2$ rule".format(ratio, cos((110.06-90)*2)**2))
# Out:
# Dynamical diffraction pi/sigma 0.605 \nCompared to 0.585 using the $\cos(2\theta)^2$ rule
